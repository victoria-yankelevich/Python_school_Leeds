# %% [markdown]
# # Exercise 2b: Arithmetic and Aggregation

# %% [markdown]
# ## Aim: Learn to do computation with xarray

# %% [markdown]
# Find the teaching materials here: https://tutorial.xarray.dev/fundamentals/03.1_computation_with_xarray.html

# %% [markdown]
# ### Issues covered:
# - Doing arithmetic on data arrays
# - Using `.mean()`, `.std()`, `.max()` and `.min()`

# %% [markdown]
# Q1. Import the `'../data/xbhubo.pgc0apr.nc'` dataset and create the temperature data array as in the last lesson.

# %%
import xarray as xr
ds = xr.load_dataset('../data/xbhubo.pgc0apr.nc')
#print (ds)
dtemp = ds['temp']
print (dtemp)
# Out:
# <xarray.DataArray 'temp' (t: 1, depth: 20, latitude: 144, longitude: 288)> Size: 3MB
# array([[[[       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          ...,
#          [-1.6890869, -1.6889343, -1.6889343, ..., -1.6904602,
#           -1.6899109, -1.6894226],
#          [-1.751648 , -1.7536316, -1.7547607, ..., -1.7432251,
#           -1.7460938, -1.7489929],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan]],
#
#         [[       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
# ...
#           -1.7268066, -1.7267761],
#          [-1.7083435, -1.7077942, -1.7072144, ..., -1.7094421,
#           -1.709198 , -1.7088013],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan]],
#
#         [[       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          ...,
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan],
#          [       nan,        nan,        nan, ...,        nan,
#                  nan,        nan]]]],
#       shape=(1, 20, 144, 288), dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * latitude   (latitude) float32 576B -89.38 -88.12 -86.88 ... 88.12 89.38
#   * depth      (depth) float32 80B 5.0 15.0 25.0 ... 4.577e+03 5.192e+03
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %% [markdown]
# Q2. Let's compare the data between the sea surface and further down. Create two temperature datasets and extract the temperature change data the sea surface and the sea bottom

# %%
dtemp.squeeze(drop=True)
# Out:
# <xarray.DataArray 'temp' (depth: 20, latitude: 144, longitude: 288)> Size: 3MB
# array([[[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         ...,
#         [-1.6890869, -1.6889343, -1.6889343, ..., -1.6904602,
#          -1.6899109, -1.6894226],
#         [-1.751648 , -1.7536316, -1.7547607, ..., -1.7432251,
#          -1.7460938, -1.7489929],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]],
#
#        [[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
# ...
#         [-1.7267456, -1.7266846, -1.726654 , ..., -1.7268372,
#          -1.7268066, -1.7267761],
#         [-1.7083435, -1.7077942, -1.7072144, ..., -1.7094421,
#          -1.709198 , -1.7088013],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]],
#
#        [[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]]], shape=(20, 144, 288), dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * latitude   (latitude) float32 576B -89.38 -88.12 -86.88 ... 88.12 89.38
#   * depth      (depth) float32 80B 5.0 15.0 25.0 ... 4.577e+03 5.192e+03
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %%
dtemp_0=dtemp.sel(depth=0, method='nearest')
dtemp_200=dtemp.sel(depth=200, method='nearest')
print('dtemp_0', dtemp_0)
print('dtemp_200', dtemp_200)
# Out:
# dtemp_0 <xarray.DataArray 'temp' (t: 1, latitude: 144, longitude: 288)> Size: 166kB
# array([[[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         ...,
#         [-1.6890869, -1.6889343, -1.6889343, ..., -1.6904602,
#          -1.6899109, -1.6894226],
#         [-1.751648 , -1.7536316, -1.7547607, ..., -1.7432251,
#          -1.7460938, -1.7489929],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]]], shape=(1, 144, 288), dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * latitude   (latitude) float32 576B -89.38 -88.12 -86.88 ... 88.12 89.38
#     depth      float32 4B 5.0
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495
# dtemp_200 <xarray.DataArray 'temp' (t: 1, latitude: 144, longitude: 288)> Size: 166kB
# array([[[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         ...,
#         [0.25024414, 0.2456665 , 0.24102783, ..., 0.26400757,
#          0.25946045, 0.2548523 ],
#         [0.08880615, 0.08605957, 0.08331299, ..., 0.09640503,
#          0.09399414, 0.09146118],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]]], shape=(1, 144, 288), dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 1kB 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * latitude   (latitude) float32 576B -89.38 -88.12 -86.88 ... 88.12 89.38
#     depth      float32 4B 203.7
#   * t          (t) object 8B 1920-04-16 00:00:00
# Attributes:
#     source:     Unified Model Output:
#     name:       temp
#     title:      POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     date:       01/12/99
#     time:       00:00
#     long_name:  POTENTIAL TEMPERATURE (OCEAN)  DEG.C
#     units:      degC
#     valid_min:  -1.7999878
#     valid_max:  35.0495

# %% [markdown]
# Q3. Calculate the difference in temperature the bottom of the ocean and the surface.

# %%
diff = dtemp_200 - dtemp_0

# %% [markdown]
# Q4. Plot the difference in these temperatures using xarrays built-in features.

# %%
diff.plot()

# %% [markdown]
# Q5. Calculate the **minimum** temperature across the water depth in all locations.

# %%
dtemp.min(dim='depth').plot()

# %% [markdown]
# Q6. Compute the global average ocean temperature change (averaged over all depths) for the entire time period in the dataset. Then display the result as a 2D depth profile.

# %%
dtemp.mean(dim='depth').plot()

# %% [markdown]
# Q7. Calculate the zonal average temperature change for each latitude. Plot the result as a 2d contour with depth on the y axis and latitude on x.
